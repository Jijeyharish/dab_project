# %%
print('Hi Hello Harish')
# Out:
# Hi Hello Harish

# %%
spark.sql('SELECT 1').show()
# Out:
# +---+
# |  1|
# +---+
# |  1|
# +---+

# %%
print(os.environ.get("DATABRICKS_RUNTIME_VERSION"))
# Out:
# None

# %%
spark.version
# Out:
# '4.1.0'
